# %%
from sage.all import randint
from collections import Counter

# Number of trials
n = 10
results = []

for _ in range(n):
    x = randint(2**2048 - 1, 2**2048)
    results.append(x)

# Count frequency of each value
freq = Counter(results)

# Print results
for value, count in freq.items():
    print(f"Value: {value}, Frequency: {count}")

# %% [markdown]
# Value: ..., Frequency: 5
# Value: ..., Frequency: 5
